# %%
import pandas as pd

# %%
df1 = pd.read_csv('../../../data/talkbank/6_0_eigsti_full.csv')
df2 = pd.read_csv('../../../data/talkbank/7_0_nadig_full.csv')
df3 = pd.read_csv('../../../data/talkbank/8_0_flusberg_full.csv')
df4 = pd.read_csv('../../../data/talkbank/9_0_rollins_full.csv')

# %%
df = pd.concat([df1, df2, df3, df4])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          171 non-null    object
#  1   age_months    171 non-null    int64
#  2   gender        171 non-null    object
#  3   group         171 non-null    object
#  4   types         171 non-null    object
#  5   corpus        171 non-null    object
#  6   investigator  171 non-null    object
#  7   mlu           171 non-null    float64
#  8   filename      171 non-null    object
#  9   all_chat      171 non-null    object
#  10  child_chat    171 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 16.0+ KB

# %%
df.reset_index(drop=True)
# Out:
#              name  age_months  gender group                types   corpus  \
# 0        Adrianne          63  female   ASD  cross, toyplay, ASD   Eigsti
# 1            Kate          45  female    TD  cross, toyplay, ASD   Eigsti
# 2            Dana          56  female   ASD  cross, toyplay, ASD   Eigsti
# 3        Meredith          40  female    TD  cross, toyplay, ASD   Eigsti
# 4            Matt          47    male   ASD  cross, toyplay, ASD   Eigsti
# ..            ...         ...     ...   ...                  ...      ...
# 166  Target_Child          39    male   ASD   long, toyplay, ASD  Rollins
# 167  Target_Child          26    male   ASD   long, toyplay, ASD  Rollins
# 168  Target_Child          35    male   ASD   long, toyplay, ASD  Rollins
# 169  Target_Child          38    male   ASD   long, toyplay, ASD  Rollins
# 170  Target_Child          41    male   ASD   long, toyplay, ASD  Rollins
#
#                       investigator       mlu filename  \
# ...

# %%
df.to_csv('../../../data/talkbank/3_0_eig_nad_flu_rol_merged.csv', index=False)

# %%
df['group'].value_counts()
# Out:
# ASD    114
# TD      41
# DD      16
# Name: group, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# male      148
# female     23
# Name: gender, dtype: int64

# %%
df5 = pd.concat([df1, df2])
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 0 to 37
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          86 non-null     object
#  1   age_months    86 non-null     int64
#  2   gender        86 non-null     object
#  3   group         86 non-null     object
#  4   types         86 non-null     object
#  5   corpus        86 non-null     object
#  6   investigator  86 non-null     object
#  7   mlu           86 non-null     float64
#  8   filename      86 non-null     int64
#  9   all_chat      86 non-null     object
#  10  child_chat    86 non-null     object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 8.1+ KB

# %%
df5.reset_index(drop=True)
# Out:
#         name  age_months  gender group                types  corpus  \
# 0   Adrianne          63  female   ASD  cross, toyplay, ASD  Eigsti
# 1       Kate          45  female    TD  cross, toyplay, ASD  Eigsti
# 2       Dana          56  female   ASD  cross, toyplay, ASD  Eigsti
# 3   Meredith          40  female    TD  cross, toyplay, ASD  Eigsti
# 4       Matt          47    male   ASD  cross, toyplay, ASD  Eigsti
# ..       ...         ...     ...   ...                  ...     ...
# 81       161          22  female    TD  cross, toyplay, ASD   Nadig
# 82       163          20    male    TD  cross, toyplay, ASD   Nadig
# 83       165          20    male    TD  cross, toyplay, ASD   Nadig
# 84       167          43  female    TD  cross, toyplay, ASD   Nadig
# 85       169          42    male    TD  cross, toyplay, ASD   Nadig
#
#                     investigator       mlu  filename  \
# 0      Jenny, Inge-Marie, Mother  4.402439      1010
# ...

# %%
df5.to_csv('../../../data/talkbank/4_0_eigsti_nadig_merged.csv')

# %%
df6 = pd.concat([df3, df4])
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          85 non-null     object
#  1   age_months    85 non-null     int64
#  2   gender        85 non-null     object
#  3   group         85 non-null     object
#  4   types         85 non-null     object
#  5   corpus        85 non-null     object
#  6   investigator  85 non-null     object
#  7   mlu           85 non-null     float64
#  8   filename      85 non-null     object
#  9   all_chat      85 non-null     object
#  10  child_chat    85 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 8.0+ KB

# %%
df6.reset_index(drop=True)
# Out:
#             name  age_months gender group               types    corpus  \
# 0   Target_Child          68   male   ASD  long, toyplay, ASD  Flusberg
# 1   Target_Child          70   male   ASD  long, toyplay, ASD  Flusberg
# 2   Target_Child          72   male   ASD  long, toyplay, ASD  Flusberg
# 3   Target_Child          74   male   ASD  long, toyplay, ASD  Flusberg
# 4   Target_Child          76   male   ASD  long, toyplay, ASD  Flusberg
# ..           ...         ...    ...   ...                 ...       ...
# 80  Target_Child          39   male   ASD  long, toyplay, ASD   Rollins
# 81  Target_Child          26   male   ASD  long, toyplay, ASD   Rollins
# 82  Target_Child          35   male   ASD  long, toyplay, ASD   Rollins
# 83  Target_Child          38   male   ASD  long, toyplay, ASD   Rollins
# 84  Target_Child          41   male   ASD  long, toyplay, ASD   Rollins
#
#                      investigator       mlu filename  \
# ...

# %%
df6.to_csv('../../../data/talkbank/5_0_flusberg_rollins_merged.csv')
