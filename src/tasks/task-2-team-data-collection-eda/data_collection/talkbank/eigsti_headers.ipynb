# %%
pip install pylangacq
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pylangacq
#   Downloading pylangacq-0.17.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: tabulate[widechars]>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from pylangacq) (0.8.10)
# Requirement already satisfied: requests>=2.18.0 in /usr/local/lib/python3.8/dist-packages (from pylangacq) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pylangacq) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.0.0->pylangacq) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.0->pylangacq) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.0->pylangacq) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.0->pylangacq) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.18.0->pylangacq) (2022.12.7)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from tabulate[widechars]>=0.8.9->pylangacq) (0.2.6)
# Installing collected packages: pylangacq
# Successfully installed pylangacq-0.17.0

# %%
import pylangacq as pla
import pandas as pd
import os

pd.options.display.max_columns = None

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
url = '/content/gdrive/MyDrive/Omdena_Sri_Lanka/project_autism/task-2-data-eda/data/textual/zip_files/Eigsti.zip'
eigsti = pla.read_chat(url)
eigsti.n_files()
# Out:
# 48

# %%
url = '../../../data/talkbank/Eigsti.zip'
eigsti = pla.read_chat(url)
eigsti.n_files() #how many chat files are present for this data
# Out:
# 48

# %%
utterrances = eigsti.utterances(by_files=True)

# %%
column_names = ['participant', 'sentence']
df = pd.DataFrame(columns=column_names)

for chat_file in utterrances:
    for utter in chat_file:
        participant = utter.participant
        participant_line = utter.tiers[participant]
        df = df.append({'participant':participant, 'sentence':participant_line}, ignore_index=True)

# %%
df
# Out:
#       participant                                           sentence
# 0            INV2                                          alright !
# 1            INV2                               you have fun, okay ?
# 2             CHI                                             okay .
# 3            INV2                                          alright .
# 4            INV1                                 did you see this ?
# ...           ...                                                ...
# 21073         INV  but, if the moon was a girl, would it be as sc...
# 21074         CHI                                             yeah .
# 21075         INV                                              why ?
# 21076         INV                     what would be scary about it ?
# 21077         CHI                                            Sarah .
#
# [21078 rows x 2 columns]

# %%
eigsti.info(verbose=True)
# Out:
# 48 files
# 21078 utterances
# 107257 words
#        Utterance Count    Word Count  File Path
# ---  -----------------  ------------  ---------------
# #1                 357          1609  Eigsti\1010.cha
# #2                 801          3772  Eigsti\1011.cha
# #3                 862          3434  Eigsti\1012.cha
# #4                 462          2144  Eigsti\1013.cha
# #5                 738          2778  Eigsti\1017.cha
# #6                 616          2804  Eigsti\1020.cha
# #7                 491          2246  Eigsti\1022.cha
# #8                 808          4510  Eigsti\1024.cha
# #9                 564          2633  Eigsti\1025.cha
# #10                480          2509  Eigsti\1027.cha
# #11                460          1957  Eigsti\1028.cha
# #12                282          1346  Eigsti\1030.cha
# #13                313          1236  Eigsti\1031.cha
# #14                686          2827  Eigsti\1032.cha
# #15                588          2706  Eigsti\1035.cha
# #16                496          2500  Eigsti\1040.cha
# #17                189          1058  Eigsti\1041.cha
# #18                219          1059  Eigsti\1042.cha
# #19                422          1987  Eigsti\1043.cha
# #20                385          2192  Eigsti\1044.cha
# #21                343          2109  Eigsti\1045.cha
# #22                397          2366  Eigsti\1046.cha
# #23                199           854  Eigsti\1047.cha
# #24                223          1270  Eigsti\1048.cha
# #25                342          1682  Eigsti\1052.cha
# #26                432          3045  Eigsti\1054.cha
# #27                335          1951  Eigsti\1055.cha
# #28                273          1645  Eigsti\1056.cha
# #29                273          1888  Eigsti\1057.cha
# #30                314          1738  Eigsti\1058.cha
# #31                487          2762  Eigsti\1060.cha
# #32                323          1424  Eigsti\1061.cha
# #33                347          2279  Eigsti\1062.cha
# #34                231          1142  Eigsti\1063.cha
# #35                232          1164  Eigsti\1064.cha
# #36                307          1856  Eigsti\1068.cha
# #37                672          3256  Eigsti\1069.cha
# #38                618          3789  Eigsti\1070.cha
# #39                641          2985  Eigsti\1072.cha
# #40                788          3393  Eigsti\1074.cha
# #41                481          2407  Eigsti\1075.cha
# #42                497          2671  Eigsti\1076.cha
# #43                361          2014  Eigsti\1078.cha
# #44                430          2578  Eigsti\1079.cha
# #45                370          2223  Eigsti\1080.cha
# #46                361          2119  Eigsti\1081.cha
# #47                350          2059  Eigsti\1082.cha
# #48                232          1281  Eigsti\1085.cha

# %%
eigsti.headers()
# Out:
# [{'UTF8': '',
#   'PID': '11312/a-00032742-1',
#   'Window': '45_811_971_1073_38547_1_39068_0_39068_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Adrianne',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;03.10',
#     'sex': 'female',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1994, 8, 9)},
#    'INV1': {'name': 'Jenny',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1999, 12, 11)},
#   'Tape Location': 'Tape 1010-2',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032743-1',
#   'Window': '85_929_1068_849_-1_-1_27032_0_27032_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Kate',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;09.19',
#     'sex': 'female',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 2, 17)},
#    'MOT': {'name': 'Eileen',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'INV1': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Michelle',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1999, 12, 6)},
#   'Tape Location': 'Tape 1011, 27:55',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032744-1',
#   'Window': '45_948_1008_948_0_0_299_0_299_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Dana',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;08.14',
#     'sex': 'female',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 3, 21)},
#    'INV1': {'name': 'Jenny',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1999, 12, 5)},
#   'Tape Location': 'Tape 1012, 40:00',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032745-1',
#   'Window': '45_709_1055_1089_0_0_287_0_287_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Meredith',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;04.22',
#     'sex': 'female',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''},
#    'INV1': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Comment': 'cross, toyplay',
#   'Date': {datetime.date(1999, 12, 11)},
#   'Tape Location': 'Tape 1013, 41:25',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032746-1',
#   'Window': '45_945_1076_1045_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Matt',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;11.13',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 2, 17)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 1, 30)},
#   'Tape Location': 'Tape 1017',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032747-1',
#   'Window': '45_908_1049_953_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Dylan',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;03.09',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 11, 22)},
#    'INV': {'name': 'Amy',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 1)},
#   'Tape Location': 'Tape 1020, realtime 7:44',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032748-1',
#   'Window': '85_885_1024_1037_-1_-1_4180_0_4180_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Mary',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;00.01',
#     'sex': 'female',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 2, 19)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 2, 20)},
#   'Tape Location': 'Tape 1022, 11:33 hard time',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032749-1',
#   'Window': '45_940_1043_991_109410_1_109819_0_109819_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Emily',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;01.01',
#     'sex': 'female',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 2, 17)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 4)},
#   'Tape Location': 'Tape 1024,',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032750-1',
#   'Window': '85_924_1062_985_-1_-1_17895_0_17895_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Tim',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;11.00',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Comment': 'cross, toyplay',
#   'Date': {datetime.date(2000, 2, 29)},
#   'Tape Location': 'Tape 1025, 38:24',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032751-1',
#   'Window': '45_835_1009_915_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Cody',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;10.12',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 4, 23)},
#    'INV': {'name': 'Jess',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 5)},
#   'Tape Location': 'Tape 1027, hardtime 12:13',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032752-1',
#   'Window': '45_949_1082_939_46203_1_46498_0_46498_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Jake',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;04.14',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1994, 10, 23)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 15)},
#   'Tape Location': '44:45',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032753-1',
#   'Window': '45_884_931_845_0_0_320_0_320_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Frankie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;10.05',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 6, 6)},
#    'INV1': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge_Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 1)},
#   'Tape Location': 'Tape 1030',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032754-1',
#   'Window': '45_884_1107_1095_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'David',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;04.09',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 11, 4)},
#    'INV': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 4)},
#   'Tape Location': 'Tape 1031, 23:38',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032755-1',
#   'Window': '45_852_1055_946_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'John',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '6;06.09',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1993, 9, 4)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 13)},
#   'Tape Location': '22:15',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032756-1',
#   'Window': '45_924_1011_951_63273_1_63722_0_63722_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Christian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;07.15',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1994, 6, 30)},
#    'FAT': {'name': 'Father',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Father',
#     'education': '',
#     'custom': ''},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 22)},
#   'Tape Location': 'Tape 1035',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032757-1',
#   'Window': '45_963_1016_976_58862_1_59164_0_59164_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Nikolette',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;11.19',
#     'sex': 'female',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 4, 26)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 15)},
#   'Tape Location': 'Tape 1040, 00.12',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032758-1',
#   'Window': '45_938_1008_880_418_1_1012_0_1012_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Shaun',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;00.24',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 3, 3)},
#    'INV1': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 27)},
#   'Location': 'Tape 1042-1041, Hardtime 7:04 to 7:24 p.m.',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032759-1',
#   'Window': '45_902_1051_939_25274_1_25596_0_25596_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Steven',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;00.24',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 3, 3)},
#    'INV1': {'name': 'Inge_Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 27)},
#   'Tape Location': 'Tape 1042-1041, hardtim 6:25 p.m.',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032760-1',
#   'Window': '45_927_1039_832_47303_1_47530_0_47530_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Rebecca',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;10.06',
#     'sex': 'female',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 5, 24)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'FAT': {'name': 'Father',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Father',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 3, 20)},
#   'Location': 'Tape 1043, Hardtime 2:14 pm',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032761-1',
#   'Window': '45_829_1063_923_0_0_381_0_381_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'David',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;00.12',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 5, 8)},
#    'INV1': {'name': 'Lauren',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 20)},
#   'Location': 'Tape 1044',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032762-1',
#   'Window': '45_876_1028_866_0_0_195_0_195_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Patrick',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;11.05',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1994, 5, 2)},
#    'INV1': {'name': 'Doug',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 9)},
#   'Location': 'Tape 1045',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032763-1',
#   'Window': '45_967_1075_980_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Alex',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;07.15',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 7, 31)},
#    'INV1': {'name': 'Doug',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge_Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 16)},
#   'Location': 'Tape 1046',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032764-1',
#   'Window': '45_914_1027_967_0_0_290_0_290_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Rebecca',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;07.05',
#     'sex': 'female',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 9, 11)},
#    'INV1': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 16)},
#   'Location': 'Tape 1047',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032765-1',
#   'Window': '56_1086_1021_807_1342_1_1784_0_1784_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Keith',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;07.15',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 8, 23)},
#    'INV1': {'name': 'Michelle',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 8)},
#   'Location': 'Tape 1048, hardtime 11:40',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032766-1',
#   'Window': '85_948_1073_989_-1_-1_4618_0_4618_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Devon',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;02.25',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 1, 17)},
#    'INV1': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'SIB': {'name': 'Brittany',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Sibling',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 12)},
#   'Location': 'Tape 1051-1052.',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032767-1',
#   'Window': '45_996_1067_1008_0_0_101_0_101_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Emily',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;02.20',
#     'sex': 'female',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 1, 27)},
#    'INV1': {'name': 'Amy',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge_Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 17)},
#   'Location': 'Tape 1054, 00:00, realtime',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032768-1',
#   'Window': '85_911_1041_984_-1_-1_9613_0_9613_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Aaron',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;06.12',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 11, 11)},
#    'INV1': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 23)},
#   'Location': 'Tape 1055',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032769-1',
#   'Window': '85_864_1075_1037_-1_-1_6438_0_6438_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Michael',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;01.24',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 2, 24)},
#    'INV': {'name': 'Investigator',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 18)},
#   'Tape Location': 'Tape 1056',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032770-1',
#   'Window': '45_904_1054_954_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'JC',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '04;10.12',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 6, 7)},
#    'INV1': {'name': 'Doug',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 19)},
#   'Location': 'Tape 1057',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032771-1',
#   'Window': '45_955_1036_937_2225_1_2578_0_2578_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Donald',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;02.26',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 2, 10)},
#    'INV1': {'name': 'Jessica',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 6)},
#   'Location': 'Tape 1058',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032772-1',
#   'Window': '85_959_1084_961_-1_-1_11797_0_11797_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Ray',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;09.16',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 7, 8)},
#    'INV1': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Jenny',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 24)},
#   'Tape Location': 'Tape 1060',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032773-1',
#   'Window': '45_958_1083_943_33777_1_34103_0_34103_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'David',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;07.21',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Comment': 'cross, toyplay',
#   'Date': {datetime.date(2000, 4, 24)},
#   'Location': 'Tape 1061, 34',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032774-1',
#   'Window': '85_895_1054_901_-1_-1_9736_0_9736_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Robbie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;03.23',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 10, 4)},
#    'INV1': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Doug',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 27)},
#   'Tape Location': 'Tape 1062',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032775-1',
#   'Window': '45_895_1054_956_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Kurtis',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '6;06.26',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1993, 10, 3)},
#    'INV1': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 29)},
#   'Location': 'Tape 1063, hardtime.',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032776-1',
#   'Window': '45_970_1085_972_27643_1_28089_0_28089_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Chris',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;11.18',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 5, 11)},
#    'INV1': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Brian',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 4, 29)},
#   'Tape Location': 'Tape 1064, 33:24',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032777-1',
#   'Window': '48_950_1062_1001_42469_1_42823_0_42823_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Kevin',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;10.13',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 7, 4)},
#    'INV1': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 17)},
#   'Tape Location': 'Tape 1068, 1:03:56 to 1:17:05',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032778-1',
#   'Window': '45_971_1064_964_78360_1_78810_0_78810_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Javon',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;10.14',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 7, 5)},
#    'INV': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 19)},
#   'Tape Location': 'Tape 1069, 1:28:15 running time',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032779-1',
#   'Window': '45_987_1085_882_0_0_290_0_290_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Evan',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;04.01',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 1, 19)},
#    'INV1': {'name': 'Lauren',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'FAT': {'name': 'Father',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Father',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 20)},
#   'Location': 'Tape 1070',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032780-1',
#   'Window': '45_886_1062_998_74725_1_75054_0_75054_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Adam',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;02.18',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 3, 6)},
#    'INV': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'SIS': {'name': 'Sister',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Sister',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 5, 24)},
#   'Tape Location': 'Tape 1072 number1, 37:56 running time; Tape 1072 number2 (JUN 16) 10:24 hard time',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032781-1',
#   'Window': '85_914_1070_929_-1_-1_28079_0_28079_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Adam',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;07.18',
#     'sex': 'male',
#     'group': 'DD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1994, 11, 11)},
#    'INV1': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 6, 28)},
#   'Tape Location': 'Tape 1074, 12:35',
#   'Comment': 'New transcription begins 36.25.',
#   'Types': 'cross, toyplay, ASD',
#   'New Episode': ''},
#  {'UTF8': '',
#   'PID': '11312/a-00032782-1',
#   'Window': '45_932_1060_943_58343_1_58767_0_58767_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Max',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;00.06',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 6, 30)},
#    'INV': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 7, 6)},
#   'Location': 'Tape 1075, hardtime 11:14',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032783-1',
#   'Window': '45_849_1054_1044_0_0_633_0_633_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Alex',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;00.19',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 6, 18)},
#    'INV1': {'name': 'Kek',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 7, 7)},
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032784-1',
#   'Window': '45_923_1098_1033_45479_1_45720_0_45720_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'David',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '2;08.18',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 11, 13)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOM': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 8, 1)},
#   'Location': 'Tape 1078, hardtime 50:02',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032785-1',
#   'Window': '85_896_1096_1026_-1_-1_3527_0_3527_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Liam',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '3;00.16',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 7, 17)},
#    'INV1': {'name': 'Lauren',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 8, 3)},
#   'Location': 'Tape 1079, 43:47',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032786-1',
#   'Window': '45_873_1087_894_51741_1_52097_1_52097_1',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Jack',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '2;09.05',
#     'sex': 'male',
#     'group': 'TD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1997, 11, 18)},
#    'INV': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 8, 23)},
#   'Location': 'Tape 1080, hardtime 11:30',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032787-1',
#   'Window': '45_885_1077_961_0_0_0_0_0_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Robbie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;08.09',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1994, 12, 19)},
#    'INV1': {'name': 'Josh',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOM': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 8, 31)},
#   'Location': 'Tape 1081, hardtime 0:00',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032788-1',
#   'Window': '45_843_1048_1020_0_0_313_0_313_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Alex',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '5;00.05',
#     'sex': 'male',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1995, 9, 4)},
#    'INV1': {'name': 'Josh',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'INV2': {'name': 'Inge-Marie',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''},
#    'MOM': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 9, 9)},
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/a-00032789-1',
#   'Window': '45_854_1107_1038_29112_1_29636_0_29636_0',
#   'Languages': ['eng'],
#   'Participants': {'CHI': {'name': 'Claire',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '4;02.20',
#     'sex': 'female',
#     'group': 'ASD',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': '',
#     'dob': datetime.date(1996, 7, 4)},
#    'INV': {'name': 'Josh',
#     'language': 'eng',
#     'corpus': 'Eigsti',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(2000, 9, 24)},
#   'Location': 'Tape 1085-2, hardtime 11:30',
#   'Comment': 'cross, toyplay',
#   'Types': 'cross, toyplay, ASD'}]

# %%
headers = eigsti.headers()
# df = pd.DataFrame(headers)

# %%
df1 = pd.json_normalize(headers)

# %%
df1.head(5)
# Out:
#   UTF8                 PID                                   Window Languages  \
# 0       11312/a-00032742-1  45_811_971_1073_38547_1_39068_0_39068_0     [eng]
# 1       11312/a-00032743-1    85_929_1068_849_-1_-1_27032_0_27032_0     [eng]
# 2       11312/a-00032744-1          45_948_1008_948_0_0_299_0_299_0     [eng]
# 3       11312/a-00032745-1         45_709_1055_1089_0_0_287_0_287_0     [eng]
# 4       11312/a-00032746-1             45_945_1076_1045_0_0_0_0_0_0     [eng]
#
#            Date     Tape Location         Comment                Types  \
# 0  {1999-12-11}       Tape 1010-2  cross, toyplay  cross, toyplay, ASD
# 1  {1999-12-06}  Tape 1011, 27:55  cross, toyplay  cross, toyplay, ASD
# 2  {1999-12-05}  Tape 1012, 40:00  cross, toyplay  cross, toyplay, ASD
# 3  {1999-12-11}  Tape 1013, 41:25  cross, toyplay  cross, toyplay, ASD
# 4  {2000-01-30}         Tape 1017  cross, toyplay  cross, toyplay, ASD
#
#   Participants.CHI.name Participants.CHI.language Participants.CHI.corpus  \
# 0              Adrianne                       eng                  Eigsti
# 1                  Kate                       eng                  Eigsti
# 2                  Dana                       eng                  Eigsti
# 3              Meredith                       eng                  Eigsti
# 4                  Matt                       eng                  Eigsti
#
#   Participants.CHI.age Participants.CHI.sex Participants.CHI.group  \
# 0              5;03.10               female                    ASD
# 1              3;09.19               female                     TD
# 2              4;08.14               female                    ASD
# 3              3;04.22               female                     TD
# 4              3;11.13                 male                    ASD
#
#   Participants.CHI.ses Participants.CHI.role Participants.CHI.education  \
# 0                               Target_Child
# 1                               Target_Child
# 2                               Target_Child
# 3                               Target_Child
# 4                               Target_Child
#
#   Participants.CHI.custom Participants.CHI.dob Participants.INV1.name  \
# 0                                   1994-08-09                  Jenny
# 1                                   1996-02-17             Inge-Marie
# 2                                   1995-03-21                  Jenny
# 3                                          NaN                  Brian
# 4                                   1996-02-17                    NaN
#
#   Participants.INV1.language Participants.INV1.corpus Participants.INV1.age  \
# 0                        eng                   Eigsti
# 1                        eng                   Eigsti
# 2                        eng                   Eigsti
# 3                        eng                   Eigsti
# 4                        NaN                      NaN                   NaN
#
#   Participants.INV1.sex Participants.INV1.group Participants.INV1.ses  \
# 0
# 1
# 2
# 3
# 4                   NaN                     NaN                   NaN
#
#   Participants.INV1.role Participants.INV1.education Participants.INV1.custom  \
# 0           Investigator
# 1           Investigator
# 2           Investigator
# 3           Investigator
# 4                    NaN                         NaN                      NaN
#
#   Participants.INV2.name Participants.INV2.language Participants.INV2.corpus  \
# 0             Inge-Marie                        eng                   Eigsti
# 1               Michelle                        eng                   Eigsti
# 2             Inge-Marie                        eng                   Eigsti
# 3             Inge-Marie                        eng                   Eigsti
# 4                    NaN                        NaN                      NaN
#
#   Participants.INV2.age Participants.INV2.sex Participants.INV2.group  \
# 0
# 1
# 2
# 3
# 4                   NaN                   NaN                     NaN
#
#   Participants.INV2.ses Participants.INV2.role Participants.INV2.education  \
# 0                                 Investigator
# 1                                 Investigator
# 2                                 Investigator
# 3                                 Investigator
# 4                   NaN                    NaN                         NaN
#
#   Participants.INV2.custom Participants.MOT.name Participants.MOT.language  \
# 0                                         Mother                       eng
# 1                                         Eileen                       eng
# 2                                         Mother                       eng
# 3                                            NaN                       NaN
# 4                      NaN                Mother                       eng
#
#   Participants.MOT.corpus Participants.MOT.age Participants.MOT.sex  \
# 0                  Eigsti
# 1                  Eigsti
# 2                  Eigsti
# 3                     NaN                  NaN                  NaN
# 4                  Eigsti
#
#   Participants.MOT.group Participants.MOT.ses Participants.MOT.role  \
# 0                                                            Mother
# 1                                                            Mother
# 2                                                            Mother
# 3                    NaN                  NaN                   NaN
# 4                                                            Mother
#
#   Participants.MOT.education Participants.MOT.custom Participants.INV.name  \
# 0                                                                      NaN
# 1                                                                      NaN
# 2                                                                      NaN
# 3                        NaN                     NaN                   NaN
# 4                                                               Inge-Marie
#
#   Participants.INV.language Participants.INV.corpus Participants.INV.age  \
# 0                       NaN                     NaN                  NaN
# 1                       NaN                     NaN                  NaN
# 2                       NaN                     NaN                  NaN
# 3                       NaN                     NaN                  NaN
# 4                       eng                  Eigsti
#
#   Participants.INV.sex Participants.INV.group Participants.INV.ses  \
# 0                  NaN                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
# 2                  NaN                    NaN                  NaN
# 3                  NaN                    NaN                  NaN
# 4
#
#   Participants.INV.role Participants.INV.education Participants.INV.custom  \
# 0                   NaN                        NaN                     NaN
# 1                   NaN                        NaN                     NaN
# 2                   NaN                        NaN                     NaN
# 3                   NaN                        NaN                     NaN
# 4          Investigator
#
#   Participants.FAT.name Participants.FAT.language Participants.FAT.corpus  \
# 0                   NaN                       NaN                     NaN
# 1                   NaN                       NaN                     NaN
# 2                   NaN                       NaN                     NaN
# 3                   NaN                       NaN                     NaN
# 4                   NaN                       NaN                     NaN
#
#   Participants.FAT.age Participants.FAT.sex Participants.FAT.group  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Participants.FAT.ses Participants.FAT.role Participants.FAT.education  \
# 0                  NaN                   NaN                        NaN
# 1                  NaN                   NaN                        NaN
# 2                  NaN                   NaN                        NaN
# 3                  NaN                   NaN                        NaN
# 4                  NaN                   NaN                        NaN
#
#   Participants.FAT.custom Location Participants.SIB.name  \
# 0                     NaN      NaN                   NaN
# 1                     NaN      NaN                   NaN
# 2                     NaN      NaN                   NaN
# 3                     NaN      NaN                   NaN
# 4                     NaN      NaN                   NaN
#
#   Participants.SIB.language Participants.SIB.corpus Participants.SIB.age  \
# 0                       NaN                     NaN                  NaN
# 1                       NaN                     NaN                  NaN
# 2                       NaN                     NaN                  NaN
# 3                       NaN                     NaN                  NaN
# 4                       NaN                     NaN                  NaN
#
#   Participants.SIB.sex Participants.SIB.group Participants.SIB.ses  \
# 0                  NaN                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
# 2                  NaN                    NaN                  NaN
# 3                  NaN                    NaN                  NaN
# 4                  NaN                    NaN                  NaN
#
#   Participants.SIB.role Participants.SIB.education Participants.SIB.custom  \
# 0                   NaN                        NaN                     NaN
# 1                   NaN                        NaN                     NaN
# 2                   NaN                        NaN                     NaN
# 3                   NaN                        NaN                     NaN
# 4                   NaN                        NaN                     NaN
#
#   Participants.SIS.name Participants.SIS.language Participants.SIS.corpus  \
# 0                   NaN                       NaN                     NaN
# 1                   NaN                       NaN                     NaN
# 2                   NaN                       NaN                     NaN
# 3                   NaN                       NaN                     NaN
# 4                   NaN                       NaN                     NaN
#
#   Participants.SIS.age Participants.SIS.sex Participants.SIS.group  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Participants.SIS.ses Participants.SIS.role Participants.SIS.education  \
# 0                  NaN                   NaN                        NaN
# 1                  NaN                   NaN                        NaN
# 2                  NaN                   NaN                        NaN
# 3                  NaN                   NaN                        NaN
# 4                  NaN                   NaN                        NaN
#
#   Participants.SIS.custom New Episode Participants.MOM.name  \
# 0                     NaN         NaN                   NaN
# 1                     NaN         NaN                   NaN
# 2                     NaN         NaN                   NaN
# 3                     NaN         NaN                   NaN
# 4                     NaN         NaN                   NaN
#
#   Participants.MOM.language Participants.MOM.corpus Participants.MOM.age  \
# 0                       NaN                     NaN                  NaN
# 1                       NaN                     NaN                  NaN
# 2                       NaN                     NaN                  NaN
# 3                       NaN                     NaN                  NaN
# 4                       NaN                     NaN                  NaN
#
#   Participants.MOM.sex Participants.MOM.group Participants.MOM.ses  \
# 0                  NaN                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
# 2                  NaN                    NaN                  NaN
# 3                  NaN                    NaN                  NaN
# 4                  NaN                    NaN                  NaN
#
#   Participants.MOM.role Participants.MOM.education Participants.MOM.custom
# 0                   NaN                        NaN                     NaN
# 1                   NaN                        NaN                     NaN
# 2                   NaN                        NaN                     NaN
# 3                   NaN                        NaN                     NaN
# 4                   NaN                        NaN                     NaN

# %%
df1.columns.tolist()
# Out:
# ['UTF8',
#  'PID',
#  'Window',
#  'Languages',
#  'Date',
#  'Tape Location',
#  'Comment',
#  'Types',
#  'Participants.CHI.name',
#  'Participants.CHI.language',
#  'Participants.CHI.corpus',
#  'Participants.CHI.age',
#  'Participants.CHI.sex',
#  'Participants.CHI.group',
#  'Participants.CHI.ses',
#  'Participants.CHI.role',
#  'Participants.CHI.education',
#  'Participants.CHI.custom',
#  'Participants.CHI.dob',
#  'Participants.INV1.name',
#  'Participants.INV1.language',
#  'Participants.INV1.corpus',
#  'Participants.INV1.age',
#  'Participants.INV1.sex',
#  'Participants.INV1.group',
#  'Participants.INV1.ses',
#  'Participants.INV1.role',
#  'Participants.INV1.education',
#  'Participants.INV1.custom',
#  'Participants.INV2.name',
#  'Participants.INV2.language',
#  'Participants.INV2.corpus',
#  'Participants.INV2.age',
#  'Participants.INV2.sex',
#  'Participants.INV2.group',
#  'Participants.INV2.ses',
#  'Participants.INV2.role',
#  'Participants.INV2.education',
#  'Participants.INV2.custom',
#  'Participants.MOT.name',
#  'Participants.MOT.language',
#  'Participants.MOT.corpus',
#  'Participants.MOT.age',
#  'Participants.MOT.sex',
#  'Participants.MOT.group',
#  'Participants.MOT.ses',
#  'Participants.MOT.role',
#  'Participants.MOT.education',
#  'Participants.MOT.custom',
#  'Participants.INV.name',
#  'Participants.INV.language',
#  'Participants.INV.corpus',
#  'Participants.INV.age',
#  'Participants.INV.sex',
#  'Participants.INV.group',
#  'Participants.INV.ses',
#  'Participants.INV.role',
#  'Participants.INV.education',
#  'Participants.INV.custom',
#  'Participants.FAT.name',
#  'Participants.FAT.language',
#  'Participants.FAT.corpus',
#  'Participants.FAT.age',
#  'Participants.FAT.sex',
#  'Participants.FAT.group',
#  'Participants.FAT.ses',
#  'Participants.FAT.role',
#  'Participants.FAT.education',
#  'Participants.FAT.custom',
#  'Location',
#  'Participants.SIB.name',
#  'Participants.SIB.language',
#  'Participants.SIB.corpus',
#  'Participants.SIB.age',
#  'Participants.SIB.sex',
#  'Participants.SIB.group',
#  'Participants.SIB.ses',
#  'Participants.SIB.role',
#  'Participants.SIB.education',
#  'Participants.SIB.custom',
#  'Participants.SIS.name',
#  'Participants.SIS.language',
#  'Participants.SIS.corpus',
#  'Participants.SIS.age',
#  'Participants.SIS.sex',
#  'Participants.SIS.group',
#  'Participants.SIS.ses',
#  'Participants.SIS.role',
#  'Participants.SIS.education',
#  'Participants.SIS.custom',
#  'New Episode',
#  'Participants.MOM.name',
#  'Participants.MOM.language',
#  'Participants.MOM.corpus',
#  'Participants.MOM.age',
#  'Participants.MOM.sex',
#  'Participants.MOM.group',
#  'Participants.MOM.ses',
#  'Participants.MOM.role',
#  'Participants.MOM.education',
#  'Participants.MOM.custom']

# %%
df2 = df1[
    ['Date', 'Types',
    'Participants.CHI.name',
	'Participants.CHI.language',
	'Participants.CHI.corpus',
	'Participants.CHI.age',
	'Participants.CHI.sex',
	'Participants.CHI.group',
 	'Participants.INV.name',
 	'Participants.INV1.name',
    'Participants.INV2.name',
    'Participants.MOT.name',]]

# %%
df2.head(2)
# Out:
#            Date                Types Participants.CHI.name  \
# 0  {1999-12-11}  cross, toyplay, ASD              Adrianne
# 1  {1999-12-06}  cross, toyplay, ASD                  Kate
#
#   Participants.CHI.language Participants.CHI.corpus Participants.CHI.age  \
# 0                       eng                  Eigsti              5;03.10
# 1                       eng                  Eigsti              3;09.19
#
#   Participants.CHI.sex Participants.CHI.group Participants.INV.name  \
# 0               female                    ASD                   NaN
# 1               female                     TD                   NaN
#
#   Participants.INV1.name Participants.INV2.name Participants.MOT.name
# 0                  Jenny             Inge-Marie                Mother
# 1             Inge-Marie               Michelle                Eileen

# %%
def convert_to_months(value):
    years, months_days = value.split(';')
    months, days = months_days.split('.')
    return 12 * int(years) + int(months)

# %%
df2['age_months'] = df2['Participants.CHI.age'].apply(convert_to_months)
del(df2['Participants.CHI.age'])

# %%
df2.head(2)
# Out:
#            Date                Types Participants.CHI.name  \
# 0  {1999-12-11}  cross, toyplay, ASD              Adrianne
# 1  {1999-12-06}  cross, toyplay, ASD                  Kate
#
#   Participants.CHI.language Participants.CHI.corpus Participants.CHI.sex  \
# 0                       eng                  Eigsti               female
# 1                       eng                  Eigsti               female
#
#   Participants.CHI.group Participants.INV.name Participants.INV1.name  \
# 0                    ASD                   NaN                  Jenny
# 1                     TD                   NaN             Inge-Marie
#
#   Participants.INV2.name Participants.MOT.name  age_months
# 0             Inge-Marie                Mother          63
# 1               Michelle                Eileen          45

# %%
df2.rename(columns=lambda x: x.replace("Participants.CHI.", ""), inplace=True)
df2.rename(columns={
    'Date': 'date', 'Types': 'types', 'sex': 'gender'}, inplace=True)
df2.head(2)
# Out:
#            date                types      name language  corpus  gender group  \
# 0  {1999-12-11}  cross, toyplay, ASD  Adrianne      eng  Eigsti  female   ASD
# 1  {1999-12-06}  cross, toyplay, ASD      Kate      eng  Eigsti  female    TD
#
#   Participants.INV.name Participants.INV1.name Participants.INV2.name  \
# 0                   NaN                  Jenny             Inge-Marie
# 1                   NaN             Inge-Marie               Michelle
#
#   Participants.MOT.name  age_months
# 0                Mother          63
# 1                Eileen          45

# %%
def merge_columns(row):
    values = [str(row[col]) for col in df2.columns if col.endswith('.name')]
    values = [value for value in values if value != 'nan']
    return ', '.join(values)

df2['investigator'] = df2.apply(merge_columns, axis=1)
df2.drop(columns=[col for col in df2.columns if col.endswith('.name')], inplace=True)

# %%
df2.head()
# Out:
#            date                types      name language  corpus  gender group  \
# 0  {1999-12-11}  cross, toyplay, ASD  Adrianne      eng  Eigsti  female   ASD
# 1  {1999-12-06}  cross, toyplay, ASD      Kate      eng  Eigsti  female    TD
# 2  {1999-12-05}  cross, toyplay, ASD      Dana      eng  Eigsti  female   ASD
# 3  {1999-12-11}  cross, toyplay, ASD  Meredith      eng  Eigsti  female    TD
# 4  {2000-01-30}  cross, toyplay, ASD      Matt      eng  Eigsti    male   ASD
#
#    age_months                  investigator
# 0          63     Jenny, Inge-Marie, Mother
# 1          45  Inge-Marie, Michelle, Eileen
# 2          56     Jenny, Inge-Marie, Mother
# 3          40             Brian, Inge-Marie
# 4          47            Inge-Marie, Mother

# %%
eig_mlu = eigsti.mlu()

# %%
df2['mlu'] = eig_mlu

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          48 non-null     object
#  1   types         48 non-null     object
#  2   name          48 non-null     object
#  3   language      48 non-null     object
#  4   corpus        48 non-null     object
#  5   gender        48 non-null     object
#  6   group         48 non-null     object
#  7   age_months    48 non-null     int64
#  8   investigator  48 non-null     object
#  9   mlu           48 non-null     float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.9+ KB

# %%
df2.columns
# Out:
# Index(['date', 'types', 'name', 'language', 'corpus', 'gender', 'group',
#        'age_months', 'investigator', 'mlu'],
#       dtype='object')

# %%
columns = [
    'name', 'age_months', 'gender',
    'group', 'types', 'corpus',
    'investigator', 'mlu']
df2 = df2[columns]
df2.head()
# Out:
#        name  age_months  gender group                types  corpus  \
# 0  Adrianne          63  female   ASD  cross, toyplay, ASD  Eigsti
# 1      Kate          45  female    TD  cross, toyplay, ASD  Eigsti
# 2      Dana          56  female   ASD  cross, toyplay, ASD  Eigsti
# 3  Meredith          40  female    TD  cross, toyplay, ASD  Eigsti
# 4      Matt          47    male   ASD  cross, toyplay, ASD  Eigsti
#
#                    investigator       mlu
# 0     Jenny, Inge-Marie, Mother  4.402439
# 1  Inge-Marie, Michelle, Eileen  2.236641
# 2     Jenny, Inge-Marie, Mother  1.861244
# 3             Brian, Inge-Marie  3.898477
# 4            Inge-Marie, Mother  2.963563

# %%
df2['group'].value_counts()
# Out:
# ASD    16
# TD     16
# DD     16
# Name: group, dtype: int64

# %%
file_path = '/content/gdrive/MyDrive/Projects/sri-lanka-chapter-toddlers-autism/src/data/talkbank/chat_files/eigsti'
files = []
for filename in os.listdir(file_path):
    if os.path.isfile(os.path.join(file_path, filename)):
        files.append(os.path.join(file_path, filename))

# %%
file_path = '../../../data/talkbank/chat_files/eigsti'
files = []
for filename in os.listdir(file_path):
    if os.path.isfile(os.path.join(file_path, filename)):
        files.append(os.path.join(file_path, filename))

# %%
df3 = pd.DataFrame(columns=['filename','all_chat', 'child'])
df4 = pd.DataFrame(columns=['filename','child'])

for file in files:
    all = [] #all is used to store the concatenated speech data
    chi = []
    df = pd.read_csv(file) #reading the csv file and storing it in a dataframe
    # if df[df['participant'] == 'CHI']:
    all = ' '.join(df['sentence'].astype(str)) # concatenate the entire speech column into one single string
    temp_df = pd.DataFrame({'filename': [file.split('.')[6][-4:]],'all_chat' : [all]}) # storing the result in another dataframe temporarily
    chi = ' '.join(df[df['participant'] == 'CHI']['sentence'].astype(str)) # concatenate the entire speech column into one single string, CHI only
    temp_chi = pd.DataFrame({'filename': [file.split('.')[6][-4:]],'child' : [chi]}) # storing the result in another dataframe temporarily
    df3 = pd.concat([df3, temp_df]) # concatenating the temporary dataframe with our initialised result dataframe
    df4 = pd.concat([df4, temp_chi])
    df3['child'] = df4['child']
df3.index = range(len(df3))

# %%
df3.head()
# Out:
#   filename                                           all_chat  \
# 0     1010  alright ! you have fun, okay ? okay . alright ...
# 1     1011  we've got sort of a bumblebee theme here (be)c...
# 2     1012  alright ! yeah &=exhales . and I'm gonna [: go...
# 3     1013  did you have fun pointing at all that stuff, M...
# 4     1017  I [!!] ʌ@u [: want] stickers ! I [!!] ʌ@u [: w...
#
#                                                child
# 0  okay . did you see this ? yeah . xxx let's see...
# 1  &=counts . &=nods:no . &=nods:yes . &=looks:mo...
# 2  xxx . ooh . xxx . &=sings . &=gasps . æh@i ! g...
# 3  yeah . mm@u . &=laughs . ŋŋ@u . &=chuckles . &...
# 4  I [!!] ʌ@u [: want] stickers ! I [!!] ʌ@u [: w...

# %%
df2[['filename', 'all_chat', 'child_chat']] = df3[['filename', 'all_chat', 'child']]

# %%
df2.head()
# Out:
#        name  age_months  gender group                types  corpus  \
# 0  Adrianne          63  female   ASD  cross, toyplay, ASD  Eigsti
# 1      Kate          45  female    TD  cross, toyplay, ASD  Eigsti
# 2      Dana          56  female   ASD  cross, toyplay, ASD  Eigsti
# 3  Meredith          40  female    TD  cross, toyplay, ASD  Eigsti
# 4      Matt          47    male   ASD  cross, toyplay, ASD  Eigsti
#
#                    investigator       mlu filename  \
# 0     Jenny, Inge-Marie, Mother  4.402439     1010
# 1  Inge-Marie, Michelle, Eileen  2.236641     1011
# 2     Jenny, Inge-Marie, Mother  1.861244     1012
# 3             Brian, Inge-Marie  3.898477     1013
# 4            Inge-Marie, Mother  2.963563     1017
#
#                                             all_chat  \
# 0  alright ! you have fun, okay ? okay . alright ...
# 1  we've got sort of a bumblebee theme here (be)c...
# 2  alright ! yeah &=exhales . and I'm gonna [: go...
# 3  did you have fun pointing at all that stuff, M...
# 4  I [!!] ʌ@u [: want] stickers ! I [!!] ʌ@u [: w...
#
#                                           child_chat
# 0  okay . did you see this ? yeah . xxx let's see...
# 1  &=counts . &=nods:no . &=nods:yes . &=looks:mo...
# 2  xxx . ooh . xxx . &=sings . &=gasps . æh@i ! g...
# 3  yeah . mm@u . &=laughs . ŋŋ@u . &=chuckles . &...
# 4  I [!!] ʌ@u [: want] stickers ! I [!!] ʌ@u [: w...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          48 non-null     object
#  1   age_months    48 non-null     int64
#  2   gender        48 non-null     object
#  3   group         48 non-null     object
#  4   types         48 non-null     object
#  5   corpus        48 non-null     object
#  6   investigator  48 non-null     object
#  7   mlu           48 non-null     float64
#  8   filename      48 non-null     object
#  9   all_chat      48 non-null     object
#  10  child_chat    48 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.2+ KB

# %%
df2.to_csv('/content/gdrive/MyDrive/Projects/sri-lanka-chapter-toddlers-autism/src/tasks/task-2-team-data-collection-eda/data_collection/eigsti_full.csv', index=False)

# %%
df2.to_csv('../../../data/talkbank/6_0_eigsti_full.csv', index=False)
