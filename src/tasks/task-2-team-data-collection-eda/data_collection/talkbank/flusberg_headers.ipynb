# %%
import pylangacq as pla
import pandas as pd
import os

pd.options.display.max_columns = None

import warnings
warnings.filterwarnings("ignore")

# %%
url = '../../../data/talkbank/Flusberg.zip'
flusberg = pla.read_chat(url)
flusberg.n_files() #how many chat files are present for this data
# Out:
# 64

# %%
utterrances = flusberg.utterances(by_files=True)

# %%
column_names = ['participant', 'sentence']
df = pd.DataFrame(columns=column_names)

for chat_file in utterrances:
    for utter in chat_file:
        participant = utter.participant
        participant_line = utter.tiers[participant]
        df = df.append({'participant':participant, 'sentence':participant_line}, ignore_index=True)

# %%
df
# Out:
#       participant                                           sentence
# 0             MOT                                      that's good .
# 1             CHI             have a diet coke at the refrigerator ?
# 2             CHI                                      a milk_ball ?
# 3             MOT                                               no .
# 4             CHI                            have milk_ball please ?
# ...           ...                                                ...
# 63973         MOT                                   goodbye Stuart .
# 63974         MOT                you wanna be laying down huh [/?] ?
# 63975         CHI                                             yeah .
# 63976         MOT  you can lay down in just about one more minute...
# 63977         CHI                                             yeah .
#
# [63978 rows x 2 columns]

# %%
flusberg.info(verbose=True)
# Out:
# 64 files
# 63978 utterances
# 278276 words
#        Utterance Count    Word Count  File Path
# ---  -----------------  ------------  --------------------------
# #1                 790          3561  Flusberg\Brett\050800.cha
# #2                 885          4158  Flusberg\Brett\051002.cha
# #3                1310          6084  Flusberg\Brett\060011.cha
# #4                1225          5930  Flusberg\Brett\060207.cha
# #5                1129          5455  Flusberg\Brett\060406.cha
# #6                1270          6516  Flusberg\Brett\060622.cha
# #7                1076          5400  Flusberg\Brett\060819.cha
# #8                 976          5266  Flusberg\Brett\070101.cha
# #9                1039          5781  Flusberg\Brett\070301.cha
# #10                637          3747  Flusberg\Brett\070517.cha
# #11                747          3615  Flusberg\Jack\060900.cha
# #12               1065          4673  Flusberg\Jack\061028.cha
# #13                966          4618  Flusberg\Jack\070106.cha
# #14                810          3537  Flusberg\Jack\070315.cha
# #15               1163          5336  Flusberg\Jack\070516.cha
# #16               1315          6075  Flusberg\Jack\070726.cha
# #17               1219          4743  Flusberg\Jack\071001.cha
# #18               1185          5919  Flusberg\Jack\080012.cha
# #19                637          3334  Flusberg\Jack\080121.cha
# #20               1059          3960  Flusberg\Jack\080221.cha
# #21               1027          4806  Flusberg\Jack\080506.cha
# #22                635          3666  Flusberg\Jack\080808.cha
# #23                805          3384  Flusberg\Mark\070700.cha
# #24               1703          7254  Flusberg\Mark\070812.cha
# #25               2249          9807  Flusberg\Mark\071026.cha
# #26               1528          6385  Flusberg\Mark\080023.cha
# #27               1534          6529  Flusberg\Mark\080224.cha
# #28               1481          5660  Flusberg\Mark\080422.cha
# #29               1650          6459  Flusberg\Mark\080700.cha
# #30               1399          5757  Flusberg\Mark\080915.cha
# #31               1581          6624  Flusberg\Mark\081118.cha
# #32               1087          4322  Flusberg\Mark\090126.cha
# #33               1139          4541  Flusberg\Mark\090320.cha
# #34               1400          6009  Flusberg\Mark\090526.cha
# #35               1104          4710  Flusberg\Mark\090818.cha
# #36                950          3543  Flusberg\Rick\040700.cha
# #37                464          1909  Flusberg\Rick\050904.cha
# #38                580          2234  Flusberg\Rick\051104.cha
# #39                995          4315  Flusberg\Rick\060107.cha
# #40               1335          5006  Flusberg\Rick\060308.cha
# #41                812          3533  Flusberg\Rick\060522.cha
# #42               1257          5278  Flusberg\Rick\060818.cha
# #43               1437          6101  Flusberg\Rick\061012.cha
# #44                673          3285  Flusberg\Rick\070013.cha
# #45                915          4625  Flusberg\Rick\070215.cha
# #46                753          3945  Flusberg\Rick\070503.cha
# #47                277           975  Flusberg\Roger\030900.cha
# #48                616          2496  Flusberg\Roger\031020.cha
# #49                647          2459  Flusberg\Roger\040028.cha
# #50                920          3561  Flusberg\Roger\040309.cha
# #51                808          3358  Flusberg\Roger\040518.cha
# #52                748          3063  Flusberg\Roger\040727.cha
# #53                906          4008  Flusberg\Roger\041007.cha
# #54                784          3531  Flusberg\Roger\050006.cha
# #55                825          3648  Flusberg\Roger\050218.cha
# #56                786          3656  Flusberg\Roger\050620.cha
# #57                556          1821  Flusberg\Stuart\030400.cha
# #58                641          2357  Flusberg\Stuart\030610.cha
# #59                682          2293  Flusberg\Stuart\030806.cha
# #60                554          1951  Flusberg\Stuart\031009.cha
# #61               1029          3817  Flusberg\Stuart\040029.cha
# #62                789          2744  Flusberg\Stuart\040306.cha
# #63                695          2611  Flusberg\Stuart\040521.cha
# #64                719          2532  Flusberg\Stuart\040715.cha

# %%
flusberg.head()
# Out:
# *MOT:  that's                  good      .
# %mor:  pro:dem|that~cop|be&3S  adj|good  .
# %gra:  1|2|SUBJ 2|0|ROOT       3|2|PRED  4|2|PUNCT
#
# *CHI:  have      a          diet     coke     at        the          refrigerator    ?
# %mor:  v|have    det:art|a  n|diet   n|coke   prep|at   det:art|the  n|refrigerator  ?
# %gra:  1|0|ROOT  2|4|DET    3|4|MOD  4|1|OBJ  5|4|NJCT  6|7|DET      7|5|POBJ        8|1|PUNCT
#
# *CHI:  a          milk_ball         ?
# %mor:  det:art|a  n|+n|milk+n|ball  ?
# %gra:  1|2|DET    2|0|INCROOT       3|2|PUNCT
#
# *MOT:  no           .
# %mor:  co|no        .
# %gra:  1|0|INCROOT  2|1|PUNCT
#
# *CHI:  have      milk_ball         please     ?
# %mor:  v|have    n|+n|milk+n|ball  co|please  ?
# %gra:  1|0|ROOT  2|1|OBJ           3|1|COM    4|1|PUNCT

# %%
len(flusberg.file_paths())
# Out:
# 64

# %%
flusberg.headers()
# Out:
# [{'UTF8': '',
#   'PID': '11312/c-00005405-1',
#   'Window': '473_241_668_685_-1_-1_4453_0_4453_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;08.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 3, 19)},
#   'Comment': 'm and c sitting in kitchen at table',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005406-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;10.02',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''},
#    'INV': {'name': 'Investigator',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': '',
#     'group': '',
#     'ses': '',
#     'role': 'Investigator',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 5, 21)},
#   'Comment': 'm and c are sitting at kitchen counter',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005407-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;00.11',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 7, 30)},
#   'Comment': 'they are playing with play_dough',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005408-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;02.07',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 9, 26)},
#   'Comment': 'm and c playing with candy land board game with special number cards placed around the board so that Brett can earn number of raisins for cooperating',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005409-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;04.06',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 11, 25)},
#   'Comment': 'm and c are in living_room and m is trying to get c to practice tying his shoes using a shoe mounted onto a wooden board',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005410-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;06.22',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 2, 10)},
#   'Comment': 'm and c playing with play_dough and toy baking utensils',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005411-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;08.19',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 4, 7)},
#   'Comment': 'm and c are going to play with some clay',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005412-1',
#   'Window': '473_241_668_685_-1_-1_61515_0_61515_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;01.01',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 8, 20)},
#   'Comment': 'm and c are discussing what they are going to talk about',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005413-1',
#   'Window': '473_241_668_685_-1_-1_92214_0_92214_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;03.01',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 10, 20)},
#   'Comment': 'm and c are going to make gingerbread',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005414-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;05.17',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1987, 1, 5)},
#   'Comment': 'm holds two cards; a sad card and a happy card , which c will get depending on his behavior they sit in living room',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005415-1',
#   'Window': '473_241_668_685_-1_-1_89294_0_89294_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;09.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1984, 12, 12)},
#   'Comment': "mom's morpheme frequencies are: 59 contractible copula , 10 uncontractible copula , 17 auxiliary , 15 uncontractible auxiliary",
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005416-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;10.28',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 2, 9)},
#   'Comment': 'm and c are playing in bed+room',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005417-1',
#   'Window': '473_241_668_685_-1_-1_11325_0_11325_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;01.06',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 4, 18)},
#   'Comment': 'm and c are discussing who went to the movies',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005418-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;03.15',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 6, 27)},
#   'Comment': 'm and c and sibling in living_room with toy cars',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005419-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;05.16',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 8, 28)},
#   'Comment': 'm and c are blowing bubbles',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005420-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;07.26',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 11, 7)},
#   'Comment': 'm and c on floor together , no toys present',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005421-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;10.01',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 1, 13)},
#   'Comment': 'm and c spelling a friends name',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005422-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;00.12',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 3, 24)},
#   'Comment': 'm and c are sitting in the living room talking about what c did at school today',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005426-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;10.21',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1987, 2, 2)},
#   'Comment': 'm and c are discussing a firedrill at school',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005423-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;02.21',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 6, 2)},
#   'Comment': 'm and c are talking about the videotape and about the news',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005424-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;05.06',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 8, 18)},
#   'Comment': 'm and c are sitting in the living_room , c is fussing about having to talk and be taped',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005425-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;08.08',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 11, 20)},
#   'Comment': 'm and c sitting in living room',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005427-1',
#   'Window': '473_241_668_685_-1_-1_85170_0_85170_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;07.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1984, 10, 24)},
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005428-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;08.12',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1984, 12, 6)},
#   'Comment': 'm and c are sitting at table , m is writing and c is reading',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005429-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;10.26',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 2, 19)},
#   'Comment': 'c is eating lunch',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005430-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;00.23',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 4, 16)},
#   'Comment': 'm and c are looking at animal book',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005431-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;02.24',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 6, 17)},
#   'Comment': 'm and c are looking at story cards and writing stories on paper',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005432-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;04.22',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 8, 15)},
#   'Comment': 'm and c are talking about a trip to the zoo',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005433-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;07.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 10, 24)},
#   'Comment': "m and c are at the table with c's picture-word cards",
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005434-1',
#   'Window': '473_241_668_685_-1_-1_148351_0_148351_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;09.15',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 1, 8)},
#   'Comment': 'm and c are talking about a cooking activity at school',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005435-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '8;11.18',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 3, 11)},
#   'Comment': 'm and c sitting at a table',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005436-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '9;01.26',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 5, 20)},
#   'Comment': 'm and c sitting at table talking',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005437-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '9;03.20',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 7, 14)},
#   'Comment': "m and c are sitting at the table playing with play_dough and are talking about c's weekend",
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005438-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '9;05.26',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 9, 19)},
#   'Comment': 'm and c are sitting at the table and talking',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005439-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '9;08.18',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 12, 12)},
#   'Comment': 'm and c are at table , talking about christmas trees',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005440-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;07.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 4, 10)},
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005441-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;09.04',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 6, 14)},
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005442-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;11.04',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 8, 14)},
#   'Comment': "m and c are playing with Danny doll , c sitting on m's lap",
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005443-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;01.07',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 10, 17)},
#   'Comment': 'm and c are drawing at the chalk+board',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005444-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;03.08',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 12, 18)},
#   'Comment': 'm and c playing with mr potato head and car , c has cold',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005445-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;05.22',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 3, 4)},
#   'Comment': 'mother and child play with fisherprice farm and animals',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005446-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;08.18',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 5, 28)},
#   'Comment': 'm and c are sitting on the floor working with association picture cards',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005447-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '6;10.12',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 7, 22)},
#   'Comment': 'm and c are playing with a view master slide viewer and slides of sesame street characters',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005448-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;00.13',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 9, 23)},
#   'Comment': 'c is playing with a Mister_Potato_head doll',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005449-1',
#   'Window': '473_241_668_685_-1_-1_94769_0_94769_0',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;02.15',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 11, 25)},
#   'Comment': 'm is trying to take two blocks apart',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005450-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '7;05.03',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1987, 2, 13)},
#   'Comment': 'm and c are talking about a Mister_Potato_head figure',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005451-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '3;09.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 3, 25)},
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005452-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '3;10.20',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 5, 15)},
#   'Comment': 'c is talking now with father',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005453-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;00.28',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 7, 23)},
#   'Comment': 'm and c playing with a small doll',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005454-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;03.09',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 10, 4)},
#   'Comment': 'm and c are playing seseme street board games , selecting colored disks and matching them to circular colors on board',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005455-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;05.18',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 12, 13)},
#   'Comment': 'm and c are playing with toy doll and dining room set',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005456-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;07.27',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 2, 21)},
#   'Comment': 'c holds up a boy doll',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005457-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;10.07',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 5, 2)},
#   'Comment': 'm and c are on the rug and are playing with a living room and kitchen set',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005458-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;00.06',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 7, 1)},
#   'Comment': 'm and c are putting together a slide that marbles roll down',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005459-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;02.18',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 9, 12)},
#   'Comment': 'c has just gotten present',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005460-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '5;06.20',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1987, 1, 14)},
#   'Comment': 'c is playing with Sesame_Street house and characters',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005461-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '3;04.',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 4, 8)},
#   'Comment': 'c has just been given present from h',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005462-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '3;06.10',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 6, 18)},
#   'Comment': 'm is showing book to c',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005463-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '3;08.06',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 8, 14)},
#   'Comment': 'c sneezes',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005464-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '3;10.09',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1985, 10, 17)},
#   'Comment': 'c playing with balloon ball',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005465-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;00.29',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 1, 6)},
#   'Comment': 'm and c playing with toy farm and animals',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005466-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;03.06',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 3, 14)},
#   'Comment': 'c flying airplane and making plane sounds',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005467-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;05.21',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 5, 29)},
#   'Comment': 'c is sitting in the living_room playing with his drum set',
#   'Types': 'long, toyplay, ASD'},
#  {'UTF8': '',
#   'PID': '11312/c-00005468-1',
#   'Languages': ['eng'],
#   'Participants': {'MOT': {'name': 'Mother',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '',
#     'sex': 'female',
#     'group': '',
#     'ses': '',
#     'role': 'Mother',
#     'education': '',
#     'custom': ''},
#    'CHI': {'name': 'Target_Child',
#     'language': 'eng',
#     'corpus': 'Flusberg',
#     'age': '4;07.15',
#     'sex': 'male',
#     'group': '',
#     'ses': '',
#     'role': 'Target_Child',
#     'education': '',
#     'custom': ''}},
#   'Date': {datetime.date(1986, 7, 23)},
#   'Comment': 'm and c are sitting on the floor , m is driving a toy car around',
#   'Types': 'long, toyplay, ASD'}]

# %%
headers = flusberg.headers()
# df = pd.DataFrame(headers)

# %%
df1 = pd.json_normalize(headers)

# %%
df1.head()
# Out:
#   UTF8                 PID                               Window Languages  \
# 0       11312/c-00005405-1  473_241_668_685_-1_-1_4453_0_4453_0     [eng]
# 1       11312/c-00005406-1                                  NaN     [eng]
# 2       11312/c-00005407-1                                  NaN     [eng]
# 3       11312/c-00005408-1                                  NaN     [eng]
# 4       11312/c-00005409-1                                  NaN     [eng]
#
#            Date                                            Comment  \
# 0  {1985-03-19}                m and c sitting in kitchen at table
# 1  {1985-05-21}             m and c are sitting at kitchen counter
# 2  {1985-07-30}                   they are playing with play_dough
# 3  {1985-09-26}  m and c playing with candy land board game wit...
# 4  {1985-11-25}  m and c are in living_room and m is trying to ...
#
#                 Types Participants.MOT.name Participants.MOT.language  \
# 0  long, toyplay, ASD                Mother                       eng
# 1  long, toyplay, ASD                Mother                       eng
# 2  long, toyplay, ASD                Mother                       eng
# 3  long, toyplay, ASD                Mother                       eng
# 4  long, toyplay, ASD                Mother                       eng
#
#   Participants.MOT.corpus Participants.MOT.age Participants.MOT.sex  \
# 0                Flusberg                                    female
# 1                Flusberg                                    female
# 2                Flusberg                                    female
# 3                Flusberg                                    female
# 4                Flusberg                                    female
#
#   Participants.MOT.group Participants.MOT.ses Participants.MOT.role  \
# 0                                                            Mother
# 1                                                            Mother
# 2                                                            Mother
# 3                                                            Mother
# 4                                                            Mother
#
#   Participants.MOT.education Participants.MOT.custom Participants.CHI.name  \
# 0                                                             Target_Child
# 1                                                             Target_Child
# 2                                                             Target_Child
# 3                                                             Target_Child
# 4                                                             Target_Child
#
#   Participants.CHI.language Participants.CHI.corpus Participants.CHI.age  \
# 0                       eng                Flusberg                5;08.
# 1                       eng                Flusberg              5;10.02
# 2                       eng                Flusberg              6;00.11
# 3                       eng                Flusberg              6;02.07
# 4                       eng                Flusberg              6;04.06
#
#   Participants.CHI.sex Participants.CHI.group Participants.CHI.ses  \
# 0                 male
# 1                 male
# 2                 male
# 3                 male
# 4                 male
#
#   Participants.CHI.role Participants.CHI.education Participants.CHI.custom  \
# 0          Target_Child
# 1          Target_Child
# 2          Target_Child
# 3          Target_Child
# 4          Target_Child
#
#   Participants.INV.name Participants.INV.language Participants.INV.corpus  \
# 0                   NaN                       NaN                     NaN
# 1          Investigator                       eng                Flusberg
# 2                   NaN                       NaN                     NaN
# 3                   NaN                       NaN                     NaN
# 4                   NaN                       NaN                     NaN
#
#   Participants.INV.age Participants.INV.sex Participants.INV.group  \
# 0                  NaN                  NaN                    NaN
# 1
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Participants.INV.ses Participants.INV.role Participants.INV.education  \
# 0                  NaN                   NaN                        NaN
# 1                               Investigator
# 2                  NaN                   NaN                        NaN
# 3                  NaN                   NaN                        NaN
# 4                  NaN                   NaN                        NaN
#
#   Participants.INV.custom
# 0                     NaN
# 1
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   UTF8                        64 non-null     object
#  1   PID                         64 non-null     object
#  2   Window                      8 non-null      object
#  3   Languages                   64 non-null     object
#  4   Date                        64 non-null     object
#  5   Comment                     60 non-null     object
#  6   Types                       64 non-null     object
#  7   Participants.MOT.name       64 non-null     object
#  8   Participants.MOT.language   64 non-null     object
#  9   Participants.MOT.corpus     64 non-null     object
#  10  Participants.MOT.age        64 non-null     object
#  11  Participants.MOT.sex        64 non-null     object
#  12  Participants.MOT.group      64 non-null     object
#  13  Participants.MOT.ses        64 non-null     object
#  14  Participants.MOT.role       64 non-null     object
#  15  Participants.MOT.education  64 non-null     object
#  16  Participants.MOT.custom     64 non-null     object
#  17  Participants.CHI.name       64 non-null     object
#  18  Participants.CHI.language   64 non-null     object
#  19  Participants.CHI.corpus     64 non-null     object
#  20  Participants.CHI.age        64 non-null     object
#  21  Participants.CHI.sex        64 non-null     object
#  22  Participants.CHI.group      64 non-null     object
#  23  Participants.CHI.ses        64 non-null     object
#  24  Participants.CHI.role       64 non-null     object
#  25  Participants.CHI.education  64 non-null     object
#  26  Participants.CHI.custom     64 non-null     object
#  27  Participants.INV.name       1 non-null      object
#  28  Participants.INV.language   1 non-null      object
#  29  Participants.INV.corpus     1 non-null      object
#  30  Participants.INV.age        1 non-null      object
#  31  Participants.INV.sex        1 non-null      object
#  32  Participants.INV.group      1 non-null      object
#  33  Participants.INV.ses        1 non-null      object
#  34  Participants.INV.role       1 non-null      object
#  35  Participants.INV.education  1 non-null      object
#  36  Participants.INV.custom     1 non-null      object
# dtypes: object(37)
# memory usage: 18.6+ KB

# %%
df1.columns.tolist()
# Out:
# ['UTF8',
#  'PID',
#  'Window',
#  'Languages',
#  'Date',
#  'Comment',
#  'Types',
#  'Participants.MOT.name',
#  'Participants.MOT.language',
#  'Participants.MOT.corpus',
#  'Participants.MOT.age',
#  'Participants.MOT.sex',
#  'Participants.MOT.group',
#  'Participants.MOT.ses',
#  'Participants.MOT.role',
#  'Participants.MOT.education',
#  'Participants.MOT.custom',
#  'Participants.CHI.name',
#  'Participants.CHI.language',
#  'Participants.CHI.corpus',
#  'Participants.CHI.age',
#  'Participants.CHI.sex',
#  'Participants.CHI.group',
#  'Participants.CHI.ses',
#  'Participants.CHI.role',
#  'Participants.CHI.education',
#  'Participants.CHI.custom',
#  'Participants.INV.name',
#  'Participants.INV.language',
#  'Participants.INV.corpus',
#  'Participants.INV.age',
#  'Participants.INV.sex',
#  'Participants.INV.group',
#  'Participants.INV.ses',
#  'Participants.INV.role',
#  'Participants.INV.education',
#  'Participants.INV.custom']

# %%
df2 = df1[
    ['Types',
    'Participants.CHI.name',
	'Participants.CHI.language',
	'Participants.CHI.corpus',
	'Participants.CHI.age',
	'Participants.CHI.sex',
	'Participants.CHI.group',
 	'Participants.MOT.name',
 	'Participants.INV.name',]]

# %%
df2.head(2)
# Out:
#                 Types Participants.CHI.name Participants.CHI.language  \
# 0  long, toyplay, ASD          Target_Child                       eng
# 1  long, toyplay, ASD          Target_Child                       eng
#
#   Participants.CHI.corpus Participants.CHI.age Participants.CHI.sex  \
# 0                Flusberg                5;08.                 male
# 1                Flusberg              5;10.02                 male
#
#   Participants.CHI.group Participants.MOT.name Participants.INV.name
# 0                                       Mother                   NaN
# 1                                       Mother          Investigator

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Types                      64 non-null     object
#  1   Participants.CHI.name      64 non-null     object
#  2   Participants.CHI.language  64 non-null     object
#  3   Participants.CHI.corpus    64 non-null     object
#  4   Participants.CHI.age       64 non-null     object
#  5   Participants.CHI.sex       64 non-null     object
#  6   Participants.CHI.group     64 non-null     object
#  7   Participants.MOT.name      64 non-null     object
#  8   Participants.INV.name      1 non-null      object
# dtypes: object(9)
# memory usage: 4.6+ KB

# %%
def convert_to_months(value):
    years, months_days = value.split(';')
    months, days = months_days.split('.')
    return 12 * int(years) + int(months)

# %%
df2['age_months'] = df2['Participants.CHI.age'].apply(convert_to_months)
del(df2['Participants.CHI.age'])

# %%
df2.head(2)
# Out:
#                 Types Participants.CHI.name Participants.CHI.language  \
# 0  long, toyplay, ASD          Target_Child                       eng
# 1  long, toyplay, ASD          Target_Child                       eng
#
#   Participants.CHI.corpus Participants.CHI.sex Participants.CHI.group  \
# 0                Flusberg                 male
# 1                Flusberg                 male
#
#   Participants.MOT.name Participants.INV.name  age_months
# 0                Mother                   NaN          68
# 1                Mother          Investigator          70

# %%
df2.rename(columns=lambda x: x.replace("Participants.CHI.", ""), inplace=True)
df2.rename(columns={
    'Types': 'types', 'custom': 'name', 'sex': 'gender'}, inplace=True)
df2.head(2)
# Out:
#                 types          name language    corpus gender group  \
# 0  long, toyplay, ASD  Target_Child      eng  Flusberg   male
# 1  long, toyplay, ASD  Target_Child      eng  Flusberg   male
#
#   Participants.MOT.name Participants.INV.name  age_months
# 0                Mother                   NaN          68
# 1                Mother          Investigator          70

# %%
df2['group'] = 'ASD'

# %%
def merge_columns(row):
    values = [str(row[col]) for col in df2.columns if col.endswith('.name')]
    values = [value for value in values if value != 'nan']
    return ', '.join(values)

df2['investigator'] = df2.apply(merge_columns, axis=1)
df2.drop(columns=[col for col in df2.columns if col.endswith('.name')], inplace=True)

# %%
flu_mlu = flusberg.mlu()

# %%
df2['mlu'] = flu_mlu

# %%
df2.head(10)
# Out:
#                 types          name language    corpus gender group  \
# 0  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 1  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 2  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 3  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 4  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 5  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 6  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 7  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 8  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
# 9  long, toyplay, ASD  Target_Child      eng  Flusberg   male   ASD
#
#    age_months          investigator       mlu
# 0          68                Mother  4.127778
# 1          70  Mother, Investigator  4.295522
# 2          72                Mother  4.282528
# 3          74                Mother  4.948403
# 4          76                Mother  4.162844
# 5          78                Mother  3.958498
# 6          80                Mother  3.961702
# 7          85                Mother  4.040761
# 8          87                Mother  4.178404
# 9          89                Mother  4.818815

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   types         64 non-null     object
#  1   name          64 non-null     object
#  2   language      64 non-null     object
#  3   corpus        64 non-null     object
#  4   gender        64 non-null     object
#  5   group         64 non-null     object
#  6   age_months    64 non-null     int64
#  7   investigator  64 non-null     object
#  8   mlu           64 non-null     float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 4.6+ KB

# %%
df2.columns
# Out:
# Index(['types', 'name', 'language', 'corpus', 'gender', 'group', 'age_months',
#        'investigator', 'mlu'],
#       dtype='object')

# %%
columns = ['name', 'age_months', 'gender', 'group', 'types', 'corpus', 'investigator', 'mlu']
df2 = df2[columns]
df2
# Out:
#             name  age_months gender group               types    corpus  \
# 0   Target_Child          68   male   ASD  long, toyplay, ASD  Flusberg
# 1   Target_Child          70   male   ASD  long, toyplay, ASD  Flusberg
# 2   Target_Child          72   male   ASD  long, toyplay, ASD  Flusberg
# 3   Target_Child          74   male   ASD  long, toyplay, ASD  Flusberg
# 4   Target_Child          76   male   ASD  long, toyplay, ASD  Flusberg
# ..           ...         ...    ...   ...                 ...       ...
# 59  Target_Child          46   male   ASD  long, toyplay, ASD  Flusberg
# 60  Target_Child          48   male   ASD  long, toyplay, ASD  Flusberg
# 61  Target_Child          51   male   ASD  long, toyplay, ASD  Flusberg
# 62  Target_Child          53   male   ASD  long, toyplay, ASD  Flusberg
# 63  Target_Child          55   male   ASD  long, toyplay, ASD  Flusberg
#
#             investigator       mlu
# 0                 Mother  4.127778
# 1   Mother, Investigator  4.295522
# 2                 Mother  4.282528
# 3                 Mother  4.948403
# 4                 Mother  4.162844
# ..                   ...       ...
# 59                Mother  2.310924
# 60                Mother  2.466019
# 61                Mother  2.201835
# 62                Mother  2.314410
# 63                Mother  2.045455
#
# [64 rows x 8 columns]

# %%
df2['group'].value_counts()
# Out:
# ASD    64
# Name: group, dtype: int64

# %%
file_path = '../../../data/talkbank/chat_files/flusberg/'
files = []
for filename in os.listdir(file_path):
    if os.path.isfile(os.path.join(file_path, filename)):
        files.append(os.path.join(file_path, filename))

# %%
df3 = pd.DataFrame(columns=['filename','all_chat'])
df4 = pd.DataFrame(columns=['filename','child_chat'])

for file in files:
    all = [] #all is used to store the concatenated speech data
    chi = []
    df = pd.read_csv(file) #reading the csv file and storing it in a dataframe
    # if df[df['participant'] == 'CHI']:
    all = ' '.join(df['sentence'].astype(str)) # concatenate the entire speech column into one single string
    temp_df = pd.DataFrame({'filename': [file.split('.')[6][35:]],'all_chat' : [all]}) # storing the result in another dataframe temporarily
    chi = ' '.join(df[df['participant'] == 'CHI']['sentence'].astype(str)) # concatenate the entire speech column into one single string
    temp_chi = pd.DataFrame({'filename': [file.split('.')[6][35:]],'child' : [chi]}) # storing the result in another dataframe temporarily
    df3 = pd.concat([df3, temp_df]) # concatenating the temporary dataframe with our initialised result dataframe
    df4 = pd.concat([df4, temp_chi])
    df3['child'] = df4['child']
df3.index = range(len(df3))

# %%
df3.head()
# Out:
#   filename                                           all_chat  \
# 0   030400  you wanna open it ? open . yeah . open . crack...
# 1   030610  good boy Stuart . good boy . what's that ? loo...
# 2   030806  god bless you . bless you . can you sing “sit ...
# 3   030900  roger want some lunch ? want lunch . want some...
# 4   031009  are [/?] you ready Stuart ? huh ? what do you ...
#
#                                                child
# 0  open . cracker . car . cracker . cracker . cra...
# 1  good boy . shoe . &e [/?] +/. doll . Mikey . M...
# 2  want water . water . sit down . sit right down...
# 3  want lunch . want some lunch . have some lunch...
# 4  balloon . momma , I want balloon . balloon . I...

# %%
df2[['filename', 'all_chat', 'child_chat']] = df3[['filename', 'all_chat', 'child']]

# %%
df2.head()
# Out:
#            name  age_months gender group               types    corpus  \
# 0  Target_Child          68   male   ASD  long, toyplay, ASD  Flusberg
# 1  Target_Child          70   male   ASD  long, toyplay, ASD  Flusberg
# 2  Target_Child          72   male   ASD  long, toyplay, ASD  Flusberg
# 3  Target_Child          74   male   ASD  long, toyplay, ASD  Flusberg
# 4  Target_Child          76   male   ASD  long, toyplay, ASD  Flusberg
#
#            investigator       mlu filename  \
# 0                Mother  4.127778   030400
# 1  Mother, Investigator  4.295522   030610
# 2                Mother  4.282528   030806
# 3                Mother  4.948403   030900
# 4                Mother  4.162844   031009
#
#                                             all_chat  \
# 0  you wanna open it ? open . yeah . open . crack...
# 1  good boy Stuart . good boy . what's that ? loo...
# 2  god bless you . bless you . can you sing “sit ...
# 3  roger want some lunch ? want lunch . want some...
# 4  are [/?] you ready Stuart ? huh ? what do you ...
#
#                                           child_chat
# 0  open . cracker . car . cracker . cracker . cra...
# 1  good boy . shoe . &e [/?] +/. doll . Mikey . M...
# 2  want water . water . sit down . sit right down...
# 3  want lunch . want some lunch . have some lunch...
# 4  balloon . momma , I want balloon . balloon . I...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          64 non-null     object
#  1   age_months    64 non-null     int64
#  2   gender        64 non-null     object
#  3   group         64 non-null     object
#  4   types         64 non-null     object
#  5   corpus        64 non-null     object
#  6   investigator  64 non-null     object
#  7   mlu           64 non-null     float64
#  8   filename      64 non-null     object
#  9   all_chat      64 non-null     object
#  10  child_chat    64 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 5.6+ KB

# %%
df2.to_csv('../../../data/talkbank/8_0_flusberg_full.csv', index=False)
