# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_from_six.csv')

# %%
df.head()
# Out:
#     Age  Gender       Country       Ethnicity      testAdmin  A10  A9  A8  A7  \
# 0  32.0       1  Saudi Arabia  Middle Eastern  Family Member    0   0   1   1
# 1  30.0       1  Saudi Arabia  Middle Eastern  Family Member    0   0   1   0
# 2  36.0       0  Saudi Arabia  Middle Eastern  Family Member    0   0   0   1
# 3  36.0       1  Saudi Arabia  Middle Eastern  Family Member    0   0   0   0
# 4  36.0       1  Saudi Arabia  Middle Eastern  Family Member    0   0   0   0
#
#    A6  ...  A4  A3  A2  A1  screeningScore  familyHistory  Jaundice  \
# 0   1  ...   0   0   0   0             3.0              0       NaN
# 1   0  ...   0   1   0   0             3.0              0       NaN
# 2   0  ...   0   0   0   0             1.0              0       NaN
# 3   0  ...   0   0   0   0             0.0              1       NaN
# 4   0  ...   0   0   0   0             0.0              0       NaN
#
#                 Source  Group ASD
# 0  Kaggle-Saudi Arabia  Adult   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3763 entries, 0 to 3762
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             3759 non-null   float64
#  1   Gender          3763 non-null   int64
#  2   Country         1549 non-null   object
#  3   Ethnicity       3622 non-null   object
#  4   testAdmin       3622 non-null   object
#  5   A10             3763 non-null   int64
#  6   A9              3763 non-null   int64
#  7   A8              3763 non-null   int64
#  8   A7              3763 non-null   int64
#  9   A6              3763 non-null   int64
#  10  A5              3763 non-null   int64
#  11  A4              3763 non-null   int64
#  12  A3              3763 non-null   int64
#  13  A2              3763 non-null   int64
#  14  A1              3763 non-null   int64
#  15  screeningScore  3763 non-null   float64
#  16  familyHistory   3763 non-null   int64
# ...

# %%
df[df.Group=='Child'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2169 entries, 15 to 3762
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             2169 non-null   float64
#  1   Gender          2169 non-null   int64
#  2   Country         350 non-null    object
#  3   Ethnicity       2129 non-null   object
#  4   testAdmin       2129 non-null   object
#  5   A10             2169 non-null   int64
#  6   A9              2169 non-null   int64
#  7   A8              2169 non-null   int64
#  8   A7              2169 non-null   int64
#  9   A6              2169 non-null   int64
#  10  A5              2169 non-null   int64
#  11  A4              2169 non-null   int64
#  12  A3              2169 non-null   int64
#  13  A2              2169 non-null   int64
#  14  A1              2169 non-null   int64
#  15  screeningScore  2169 non-null   float64
#  16  familyHistory   2169 non-null   int64
# ...

# %%
df[df.Group=='Adult'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 0 to 2778
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             1590 non-null   float64
#  1   Gender          1590 non-null   int64
#  2   Country         1195 non-null   object
#  3   Ethnicity       1492 non-null   object
#  4   testAdmin       1492 non-null   object
#  5   A10             1590 non-null   int64
#  6   A9              1590 non-null   int64
#  7   A8              1590 non-null   int64
#  8   A7              1590 non-null   int64
#  9   A6              1590 non-null   int64
#  10  A5              1590 non-null   int64
#  11  A4              1590 non-null   int64
#  12  A3              1590 non-null   int64
#  13  A2              1590 non-null   int64
#  14  A1              1590 non-null   int64
#  15  screeningScore  1590 non-null   float64
#  16  familyHistory   1590 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                  4
# Gender               0
# Country           2214
# Ethnicity          141
# testAdmin          141
# A10                  0
# A9                   0
# A8                   0
# A7                   0
# A6                   0
# A5                   0
# A4                   0
# A3                   0
# A2                   0
# A1                   0
# screeningScore       0
# familyHistory        0
# Jaundice           461
# Source               0
# Group                4
# ASD                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Ethnicity', 'testAdmin', 'A10', 'A9', 'A8',
#        'A7', 'A6', 'A5', 'A4', 'A3', 'A2', 'A1', 'screeningScore',
#        'familyHistory', 'Jaundice', 'Source', 'Group', 'ASD'],
#       dtype='object')

# %%
num = ['Age','screeningScore']
cat = ['Gender', 'Country', 'Ethnicity', 'testAdmin', 'A10', 'A9', 'A8','A7', 'A6', 'A5', 'A4', 'A3', 'A2', 'A1',
       'familyHistory', 'Jaundice', 'Source','Group', 'ASD']

# %%
df[cat] = df[cat].astype('category')

# %%
df.describe()
# Out:
#                Age  screeningScore
# count  3759.000000     3763.000000
# mean     12.848053        5.214191
# std      11.635786        2.809633
# min       1.000000        0.000000
# 25%       3.000000        3.000000
# 50%       9.000000        5.000000
# 75%      19.000000        7.000000
# max      64.000000       10.000000

# %%
df[cat].describe()
# Out:
#         Gender       Country       Ethnicity      testAdmin   A10    A9    A8  \
# count     3763          1549            3622           3622  3763  3763  3763
# unique       2            89              12              8     2     2     2
# top          0  Saudi Arabia  White European  Family Member     1     0     0
# freq      2425           468            1057           1842  2185  2079  1916
#
#           A7    A6    A5    A4    A3    A2    A1  familyHistory  Jaundice  \
# count   3763  3763  3763  3763  3763  3763  3763           3763    3302.0
# unique     2     2     2     2     2     2     2              2       2.0
# top        1     1     1     0     0     0     1              0       0.0
# freq    2088  1895  1943  1914  2138  2107  2162           2775    1715.0
#
#                     Source  Group   ASD
# count                 3763   3759  3763
# unique                   6      2     2
# top     Github-Behavioural  Child     1
# freq                  1239   2169  2205

# %%
df.Ethnicity.unique()
# Out:
# ['Middle Eastern', 'Hispanic', 'Black', NaN, 'White European', ..., 'Asian', 'Pacifica', 'Turkish', 'Native Indian', 'Mixed']
# Length: 13
# Categories (12, object): ['Asian', 'Black', 'Hispanic', 'Latino', ..., 'Pacifica', 'South Asian', 'Turkish', 'White European']

# %%
fig, ax = plt.subplots(1,3,figsize=(15,5))
labels = ['Males','Females']

values1 = df['Gender'].value_counts().sort_index().values
values2 = df[df['ASD']==1]['Gender'].value_counts().sort_index().values
values3 = df[df['ASD']==0]['Gender'].value_counts().sort_index().values

explode=(0.1,0)

ax[0].pie(values1,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[0].set_title('Overall')
#ax[0].legend(frameon=False)

ax[1].pie(values2,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[1].set_title('ASD Traits-Present')
#ax[1].legend(frameon=False)

ax[2].pie(values3,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[2].set_title('ASD Traits-Absent')
ax[2].legend(title='Gender Distribution',frameon=False, loc='upper right', bbox_to_anchor=(1.8,0.7))

plt.show()

# %%
fig, ax = plt.subplots(1,3,figsize=(15,5))
labels = ['No ASD Traits','ASD Traits']

values1 = df['ASD'].value_counts().sort_index().values
values2 = df[df['Gender']==1]['ASD'].value_counts().sort_index().values
values3 = df[df['Gender']==0]['ASD'].value_counts().sort_index().values

explode=(0.1,0)

ax[0].pie(values1,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[0].set_title('Overall')
#ax[0].legend(frameon=False)

ax[1].pie(values2,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[1].set_title('Females')
#ax[1].legend(frameon=False)

ax[2].pie(values3,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[2].set_title('Males')
ax[2].legend(title='ASD Traits Distribution',frameon=False, loc='upper right', bbox_to_anchor=(1.8,0.7))

plt.show()

# %%
df[df['familyHistory']==1]['ASD'].value_counts().sort_index()
# Out:
# 0    310
# 1    678
# Name: ASD, dtype: int64

# %%
fig, ax = plt.subplots(1,3,figsize=(15,5))
labels = ['No Family History','Family History']
asd = ['No ASD Traits','ASD Traits Present']

values1 = df['familyHistory'].value_counts().sort_index().values
values2 = df[df['familyHistory']==1]['ASD'].value_counts().sort_index().values
values3 = df[df['familyHistory']==0]['ASD'].value_counts().sort_index().values

explode=(0.1,0)

ax[0].pie(values1,labels=labels,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[0].set_title('Overall')
#ax[0].legend(frameon=False)

ax[1].pie(values2,labels=asd,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[1].set_title('Present Family History')
#ax[1].legend(frameon=False)

ax[2].pie(values3,labels=asd,explode=explode,colors=['#009ACD', '#ADD8E6'],autopct='%1.1f%%',shadow=True)
ax[2].set_title('No Family History')
# ax[2].legend(title='',frameon=False, loc='upper right', bbox_to_anchor=(1.8,0.7))

plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Ethnicity', 'testAdmin', 'A10', 'A9', 'A8',
#        'A7', 'A6', 'A5', 'A4', 'A3', 'A2', 'A1', 'screeningScore',
#        'familyHistory', 'Jaundice', 'Source', 'Group', 'ASD'],
#       dtype='object')

# %%
# Bivariate Distribution and Association
p = sns.pairplot(data=df, vars=num, hue='ASD')
p.fig.suptitle('Bivariate Distribution and Association', fontsize=12, y=1.01)
plt.show()

# %%
sns.histplot(data=df, x='Age',kde=True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
sns.histplot(data=df, x='screeningScore',kde=True)
plt.title('Total Q-Chat Score Distribution')
# Out:
# Text(0.5, 1.0, 'Total Q-Chat Score Distribution')

# %%
df.Ethnicity.unique()
# Out:
# ['Middle Eastern', 'Hispanic', 'Black', NaN, 'White European', ..., 'Asian', 'Pacifica', 'Turkish', 'Native Indian', 'Mixed']
# Length: 13
# Categories (12, object): ['Asian', 'Black', 'Hispanic', 'Latino', ..., 'Pacifica', 'South Asian', 'Turkish', 'White European']

# %%
df.testAdmin.unique()
# Out:
# ['Family Member', 'Other', 'Parent', 'Relative', NaN, 'Self', 'Health Care Professional', 'Others', 'School And Ngo']
# Categories (8, object): ['Family Member', 'Health Care Professional', 'Other', 'Others', 'Parent', 'Relative', 'School And Ngo', 'Self']

# %%
fig, ax =plt.subplots(2,1, figsize=(18,12))
sns.histplot(df['Ethnicity'], ax=ax[0])
sns.histplot(df['testAdmin'], ax=ax[1])
fig.show()
# Out:
# /tmp/ipykernel_17831/2846141916.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df.corr()
# Out:
#                     Age  screeningScore
# Age             1.00000         0.00139
# screeningScore  0.00139         1.00000

# %%
# Pearson correlation stats for continuous variables

cg = sns.clustermap(df.corr(), cmap ='YlGnBu', linewidths = 0.1, annot=True, figsize=(4,4));
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg.fig.suptitle('Continuous Variables - Pearson Correlation Matrix',y=1.04, fontweight='bold')
# Out:
# Text(0.5, 1.04, 'Continuous Variables - Pearson Correlation Matrix')

# %%
# removed null rows:
df_cleaned = df.dropna()
df_cleaned.head()
# Out:
#       Age Gender         Country       Ethnicity testAdmin A10 A9 A8 A7 A6  \
# 461  15.0      0         Austria        Hispanic    Parent   0  1  1  1  1
# 462  15.0      0         Austria           Black  Relative   1  1  0  0  0
# 464  14.0      1  United Kingdom  White European      Self   0  1  1  0  1
# 468  15.0      1       Australia  Middle Eastern    Parent   1  0  1  1  0
# 469  12.0      0         Bahrain           Black    Parent   0  0  0  0  1
#
#      ... A4 A3 A2 A1 screeningScore  familyHistory Jaundice          Source  \
# 461  ...  1  0  0  0            6.0              1      1.0  UCI-Adolescent
# 462  ...  0  0  0  0            2.0              0      0.0  UCI-Adolescent
# 464  ...  1  1  1  0            7.0              0      0.0  UCI-Adolescent
# 468  ...  1  0  1  1            7.0              0      0.0  UCI-Adolescent
# 469  ...  1  1  1  1            6.0              1      1.0  UCI-Adolescent
#
#      Group ASD
# 461  Adult   0
# 462  Adult   0
# ...

# %%
df_cleaned.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Ethnicity', 'testAdmin', 'A10', 'A9', 'A8',
#        'A7', 'A6', 'A5', 'A4', 'A3', 'A2', 'A1', 'screeningScore',
#        'familyHistory', 'Jaundice', 'Source', 'Group', 'ASD'],
#       dtype='object')

# %%
cat_new=['A10', 'A9', 'A8', 'A7', 'A6', 'A5', 'A4', 'A3', 'A2', 'A1','familyHistory', 'Jaundice','Gender']

# %%
# point biserial correlation between categorical and continuous variables

from scipy.stats import pointbiserialr
print(cat)
# values=[[0]*len(categorical_att)]*len(cont_att)
values=np.zeros((len(num),len(cat_new)))
for i,x in enumerate(num):
    for j,y in enumerate(cat_new):
        # print(y,x)
        pbc = pointbiserialr(df_cleaned[y], df_cleaned[x])
        values[i][j]=pbc[0]
        # print(values[i][j])
        
fig, ax = plt.subplots(figsize=(12,3))
sns.heatmap(values,xticklabels=cat_new, yticklabels=num, annot=True, cmap='YlGnBu')
fig.suptitle('Point Biserial Correlation between categorical and continuous variables', y=1.01, fontweight='bold')
# Out:
# ['Gender', 'Country', 'Ethnicity', 'testAdmin', 'A10', 'A9', 'A8', 'A7', 'A6', 'A5', 'A4', 'A3', 'A2', 'A1', 'familyHistory', 'Jaundice', 'Source', 'Group', 'ASD']
# Text(0.5, 1.01, 'Point Biserial Correlation between categorical and continuous variables')

# %%
# Corrected Cramer’s V measure of association - Categorical Variables

from scipy.stats.contingency import association

rows= []

for var1 in df[cat]:
    col = []
    for var2 in df_cleaned[cat]:
        crosstab =np.array(pd.crosstab(df_cleaned[var1],df_cleaned[var2], rownames=None, colnames=None))
        col.append(round(association(np.array(crosstab), method="cramer"),2)) # Keeping of the rounded value of the Cramer's V  
    rows.append(col)
    
cramers_results = np.array(rows)
results = pd.DataFrame(cramers_results, columns = cat, index =cat)

fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(results, annot=True, cmap='YlGnBu')
fig.suptitle('Corrected Cramer’s V measure of association - Categorical Variables', fontweight='bold', y=0.92)
# Out:
# Text(0.5, 0.92, 'Corrected Cramer’s V measure of association - Categorical Variables')
