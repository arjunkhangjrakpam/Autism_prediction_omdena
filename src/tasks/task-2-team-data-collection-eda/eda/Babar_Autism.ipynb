# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored

# %%
df = pd.read_csv("../../../data/data_csv.csv")

# %%
df.head()
# Out:
#    CASE_NO_PATIENT'S  A1  A2  A3  A4  A5  A6  A7  A8  A9  ...  \
# 0                  1   0   0   0   0   0   0   1   1   0  ...
# 1                  2   1   1   0   0   0   1   1   0   0  ...
# 2                  3   1   0   0   0   0   0   1   1   0  ...
# 3                  4   1   1   1   1   1   1   1   1   1  ...
# 4                  5   1   1   0   1   1   1   1   1   1  ...
#
#    Global developmental delay/intellectual disability  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Social/Behavioural Issues  Childhood Autism Rating Scale  Anxiety_disorder  \
# 0                        Yes                              1               Yes
# 1                        Yes                              2               Yes
# ...

# %%
print(colored("Shape: ","green", attrs=["bold"]), df.shape)
print(colored("Information is:","green", attrs=["bold"]))
print(df.info())
# Out:
# Shape:  (1985, 28)
# Information is:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1985 entries, 0 to 1984
# Data columns (total 28 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   CASE_NO_PATIENT'S                                   1985 non-null   int64
#  1   A1                                                  1985 non-null   int64
#  2   A2                                                  1985 non-null   int64
#  3   A3                                                  1985 non-null   int64
#  4   A4                                                  1985 non-null   int64
#  5   A5                                                  1985 non-null   int64
#  6   A6                                                  1985 non-null   int64
#  7   A7                                                  1985 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['CASE_NO_PATIENT'S', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8',
#        'A9', 'A10_Autism_Spectrum_Quotient', 'Social_Responsiveness_Scale',
#        'Age_Years', 'Qchat_10_Score', 'Speech Delay/Language Disorder',
#        'Learning disorder', 'Genetic_Disorders', 'Depression',
#        'Global developmental delay/intellectual disability',
#        'Social/Behavioural Issues', 'Childhood Autism Rating Scale',
#        'Anxiety_disorder', 'Sex', 'Ethnicity', 'Jaundice',
#        'Family_mem_with_ASD', 'Who_completed_the_test', 'ASD_traits'],
#       dtype='object')

# %%
print(colored("Total number of values with respect to each features", "green", attrs=["bold"]), "\n", df.count())
# Out:
# Total number of values with respect to each features
#  CASE_NO_PATIENT'S                                     1985
# A1                                                    1985
# A2                                                    1985
# A3                                                    1985
# A4                                                    1985
# A5                                                    1985
# A6                                                    1985
# A7                                                    1985
# A8                                                    1985
# A9                                                    1985
# A10_Autism_Spectrum_Quotient                          1985
# Social_Responsiveness_Scale                           1976
# Age_Years                                             1985
# Qchat_10_Score                                        1946
# Speech Delay/Language Disorder                        1985
# ...

# %%
print(colored("Null values in each column \n ", "green", attrs=["bold"]), df.isnull().sum())
# Out:
# Null values in each column
#   CASE_NO_PATIENT'S                                      0
# A1                                                     0
# A2                                                     0
# A3                                                     0
# A4                                                     0
# A5                                                     0
# A6                                                     0
# A7                                                     0
# A8                                                     0
# A9                                                     0
# A10_Autism_Spectrum_Quotient                           0
# Social_Responsiveness_Scale                            9
# Age_Years                                              0
# Qchat_10_Score                                        39
# Speech Delay/Language Disorder                         0
# Learning disorder                                      0
# ...

# %%
df.dtypes
# Out:
# CASE_NO_PATIENT'S                                       int64
# A1                                                      int64
# A2                                                      int64
# A3                                                      int64
# A4                                                      int64
# A5                                                      int64
# A6                                                      int64
# A7                                                      int64
# A8                                                      int64
# A9                                                      int64
# A10_Autism_Spectrum_Quotient                            int64
# Social_Responsiveness_Scale                           float64
# Age_Years                                               int64
# Qchat_10_Score                                        float64
# Speech Delay/Language Disorder                         object
# ...

# %%
cat_df = df[['Speech Delay/Language Disorder','Learning disorder', 'Genetic_Disorders', 'Depression',
'Global developmental delay/intellectual disability',
'Social/Behavioural Issues','Anxiety_disorder', 'Sex', 'Ethnicity', 'Jaundice',
'Family_mem_with_ASD', 'Who_completed_the_test', 'ASD_traits']]

num_df = df[['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8',
       'A9', 'A10_Autism_Spectrum_Quotient', 'Social_Responsiveness_Scale',
       'Age_Years', 'Qchat_10_Score', 'Childhood Autism Rating Scale']]

# %%
for i in cat_df.columns:
    print(colored(i,"green", attrs=["bold"]), df[i].unique())
# Out:
# Speech Delay/Language Disorder ['Yes' 'No']
# Learning disorder ['Yes' 'No']
# Genetic_Disorders ['Yes' 'No']
# Depression ['Yes' 'No' nan]
# Global developmental delay/intellectual disability ['Yes' 'No']
# Social/Behavioural Issues ['Yes' nan 'No']
# Anxiety_disorder ['Yes' 'No']
# Sex ['F' 'M']
# Ethnicity ['middle eastern' 'White European' 'Middle Eastern' 'Hispanic' 'Black'
#  'Asian' 'South Asian' 'Native Indian' 'Others' 'black' 'asian' 'Latino'
#  'Mixed' 'south asian' 'mixed' 'PaciFica']
# Jaundice ['Yes' 'No']
# Family_mem_with_ASD ['No' 'Yes']
# Who_completed_the_test ['Family Member' 'Health Care Professional' 'Self' 'Family member'
#  'Others' 'School and NGO']
# ASD_traits ['No' 'Yes']

# %% [markdown]
# # ASD Traits

# %%
ax = sns.barplot(x=df["ASD_traits"].value_counts().index, y=df["ASD_traits"].value_counts())
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ## ASD Traits & Categorical Features

# %%
for i in cat_df.columns:
    ax = sns.barplot(x=cat_df[i].value_counts().index, y=cat_df[i].value_counts())
    plt.title(i)
    plt.xticks(rotation=90)
    ax.bar_label(ax.containers[0])
    plt.show()

# %% [markdown]
# ## Ethnicity and ASD Traits

# %%
pivot_ethnicity = pd.pivot_table(df, index="Ethnicity", columns="ASD_traits", values="Qchat_10_Score")
pivot_ethnicity
# Out:
# ASD_traits            No       Yes
# Ethnicity
# Asian           2.637500  4.706960
# Black           2.666667  7.166667
# Hispanic        2.200000  6.733333
# Latino          1.500000  6.850000
# Middle Eastern  2.986063  6.720000
# Mixed           1.000000  6.750000
# Native Indian        NaN  7.000000
# Others          2.000000  6.689655
# PaciFica        1.000000  7.857143
# South Asian     2.789474  6.700000
# White European  2.476190  4.991398
# asian           1.972527  6.193548
# black           4.800000  8.666667
# middle eastern  2.450000  6.666667
# mixed                NaN  7.000000
# south asian     3.964824  7.142857

# %%
ax = pivot_ethnicity.plot(kind="bar")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])

plt.show()

# %%
test = pd.pivot_table(df, index='Who_completed_the_test', columns="ASD_traits", values="Qchat_10_Score")
test
# Out:
# ASD_traits                      No       Yes
# Who_completed_the_test
# Family Member             3.088608  5.622356
# Family member             2.272727  6.333333
# Health Care Professional  2.786713  5.389752
# Others                         NaN  7.000000
# School and NGO                 NaN  1.000000
# Self                      1.000000  7.000000

# %%
ax = test.plot(kind="bar")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.show();

# %% [markdown]
# ## ASD Traits & Numerical Features

# %%
num_df = df[['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8',
       'A9', 'A10_Autism_Spectrum_Quotient', 'Social_Responsiveness_Scale',
       'Age_Years', 'Qchat_10_Score', 'Childhood Autism Rating Scale']]

# %%
for i in num_df.columns:
    ax = sns.histplot(num_df[i])
    plt.title(i)
    ax.bar_label(ax.containers[1])
    plt.show()

# %%
sns.heatmap(num_df.corr())
# Out:
# <AxesSubplot: >

# %%
pivot_num = pd.pivot_table(df, index="ASD_traits", values=['Social_Responsiveness_Scale',
       'Age_Years', 'Qchat_10_Score', 'Childhood Autism Rating Scale'])
pivot_num
# Out:
#             Age_Years  Childhood Autism Rating Scale  Qchat_10_Score  \
# ASD_traits
# No           9.720088                       1.478595        2.877058
# Yes          9.543762                       1.891061        5.429952
#
#             Social_Responsiveness_Scale
# ASD_traits
# No                             1.940529
# Yes                            4.038390

# %%
ax = pivot_num.plot(kind="bar")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
ax.bar_label(ax.containers[3])
ax.bar_label(ax.containers[0])
plt.show();
